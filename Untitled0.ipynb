# %% [markdown]
# <a href="https://colab.research.google.com/github/raritto-1/Daily_Practice/blob/Learning_coding/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler # remove noice, faster, handling missing data, features
from sklearn.pipeline import Pipeline #it allow the user to chaise after the code is compilted

# %%
feature_name = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude'] #rows
df = pd.DataFrame(X, columns=feature_name)#creating the datafram for pandas
df['target'] = y # give the value of y
df.dropna(inplace = True) # remove the value if its inplace is true , dropna is powerfull function which drop the row and column in pandas

# %%
from sklearn.datasets import fetch_california_housing

X, y = fetch_california_housing(return_X_y=True)

# %%
houseing  = fetch_california_housing()
feature_name = houseing.feature_names
print(feature_name)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
print(y.shape)
# Out:
# (20640,)

# %%
mod=KNeighborsRegressor().fit(X, y)

pipe = Pipeline([('scaler', StandardScaler()), ('model', KNeighborsRegressor())])

# %%
mod_l = LinearRegression()

# %%
mod_l.fit(X,y)
# Out:
# LinearRegression()

# %%
pipe.fit(X,y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', KNeighborsRegressor())])

# %%
prediction = pipe.predict(X)

# %%
plt.scatter(prediction, y)

# %%
mod_l.predict(X)
plt.scatter(y,mod_l.predict(X))
